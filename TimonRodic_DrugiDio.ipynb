# %% [markdown]
# # UZOP projekt: Preditcing NBA shots
# ## Student: Timon Rodić
# ## JMBAG: 0036529975

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Učitavanje i prikaz podataka
# Prvo učitamo csv datoteku u varijablu x.

# %%
# Ucitavanje podataka
x = pd.read_csv("shot_logs.csv")

# Prikaz podataka
x
# Out:
#          GAME_ID                   MATCHUP LOCATION  W  FINAL_MARGIN  \
# 0       21400899  MAR 04, 2015 - CHA @ BKN        A  W            24
# 1       21400899  MAR 04, 2015 - CHA @ BKN        A  W            24
# 2       21400899  MAR 04, 2015 - CHA @ BKN        A  W            24
# 3       21400899  MAR 04, 2015 - CHA @ BKN        A  W            24
# 4       21400899  MAR 04, 2015 - CHA @ BKN        A  W            24
# ...          ...                       ...      ... ..           ...
# 128064  21400006  OCT 29, 2014 - BKN @ BOS        A  L           -16
# 128065  21400006  OCT 29, 2014 - BKN @ BOS        A  L           -16
# 128066  21400006  OCT 29, 2014 - BKN @ BOS        A  L           -16
# 128067  21400006  OCT 29, 2014 - BKN @ BOS        A  L           -16
# 128068  21400006  OCT 29, 2014 - BKN @ BOS        A  L           -16
#
#         SHOT_NUMBER  PERIOD GAME_CLOCK  SHOT_CLOCK  DRIBBLES  ...  SHOT_DIST  \
# 0                 1       1       1:09        10.8         2  ...        7.7
# 1                 2       1       0:14         3.4         0  ...       28.2
# 2                 3       1       0:00         NaN         3  ...       10.1
# 3                 4       2      11:47        10.3         2  ...       17.2
# 4                 5       2      10:34        10.9         2  ...        3.7
# ...             ...     ...        ...         ...       ...  ...        ...
# 128064            5       3       1:52        18.3         5  ...        8.7
# 128065            6       4      11:28        19.8         4  ...        0.6
# 128066            7       4      11:10        23.0         2  ...       16.9
# 128067            8       4       2:37         9.1         4  ...       18.3
# 128068            9       4       0:12         NaN         5  ...        5.1
#
#         PTS_TYPE  SHOT_RESULT   CLOSEST_DEFENDER CLOSEST_DEFENDER_PLAYER_ID  \
# 0              2         made     Anderson, Alan                     101187
# 1              3       missed  Bogdanovic, Bojan                     202711
# 2              2       missed  Bogdanovic, Bojan                     202711
# 3              2       missed      Brown, Markel                     203900
# 4              2       missed    Young, Thaddeus                     201152
# ...          ...          ...                ...                        ...
# 128064         2       missed      Smart, Marcus                     203935
# 128065         2         made       Turner, Evan                     202323
# 128066         2         made   Thornton, Marcus                     201977
# 128067         2       missed     Bradley, Avery                     202340
# 128068         2         made     Bradley, Avery                     202340
#
#         CLOSE_DEF_DIST  FGM  PTS    player_name player_id
# 0                  1.3    1    2  brian roberts    203148
# 1                  6.1    0    0  brian roberts    203148
# 2                  0.9    0    0  brian roberts    203148
# 3                  3.4    0    0  brian roberts    203148
# 4                  1.1    0    0  brian roberts    203148
# ...                ...  ...  ...            ...       ...
# 128064             0.8    0    0   jarrett jack    101127
# 128065             0.6    1    2   jarrett jack    101127
# 128066             4.2    1    2   jarrett jack    101127
# 128067             3.0    0    0   jarrett jack    101127
# 128068             2.3    1    2   jarrett jack    101127
#
# [128069 rows x 21 columns]

# %% [markdown]
# # Značajke
# Mozemo vidjeti znacajke naseg skupa podataka

# %%
# Ispis značajki
x.columns.values
# Out:
# array(['GAME_ID', 'MATCHUP', 'LOCATION', 'W', 'FINAL_MARGIN',
#        'SHOT_NUMBER', 'PERIOD', 'GAME_CLOCK', 'SHOT_CLOCK', 'DRIBBLES',
#        'TOUCH_TIME', 'SHOT_DIST', 'PTS_TYPE', 'SHOT_RESULT',
#        'CLOSEST_DEFENDER', 'CLOSEST_DEFENDER_PLAYER_ID', 'CLOSE_DEF_DIST',
#        'FGM', 'PTS', 'player_name', 'player_id'], dtype=object)

# %% [markdown]
# ## Opis značajki:
# - Game_ID : identifikator odigrane tekme
# - Matchup : sadrzi datum tekme i imena timova
# - Location : binarna varijabla( A-away, H-home)
# - W : binarna varijabla (W-win, L-loss)
# - Final_Margin : Razlika u broju koševa između timova
# - Shot_Number : redni broj bacanja
# - Period : aktivna cetvrt
# - Game_Clock : vrijeme tijekom bacanja
# - Shot_Clock : preostalo vrijeme napada
# - Dribbles : broj driblinga
# - Touch_Time : vrijeme vodenja lopte prije bacanja
# - Shot_Dist : udaljenost od koša
# - PTS_type : potencialni bodovi
# - Shot_Result : da li je ostvaren pogodak
# - Closest_Defender : ime najblizeg obrambenog igraca
# - Closest_Defender_Player_ID : ID najblizeg obrambenog igraca
# - Close_Def_Dist : udaljenost najblizeg obrambenog igraca
# - FGM : field goals made; binarna varijabla za uspjesnost bacanja
# - PTS : poeni ostvareni za bacanje
# - Player_name : ime bacaca
# - Player_Id : identifikator bacaca

# %% [markdown]
# Metodom info() mozemo vidjeti kakve tipove podataka imamo.

# %%
#tipovi podataka
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128069 entries, 0 to 128068
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   GAME_ID                     128069 non-null  int64
#  1   MATCHUP                     128069 non-null  object
#  2   LOCATION                    128069 non-null  object
#  3   W                           128069 non-null  object
#  4   FINAL_MARGIN                128069 non-null  int64
#  5   SHOT_NUMBER                 128069 non-null  int64
#  6   PERIOD                      128069 non-null  int64
#  7   GAME_CLOCK                  128069 non-null  object
#  8   SHOT_CLOCK                  122502 non-null  float64
#  9   DRIBBLES                    128069 non-null  int64
#  10  TOUCH_TIME                  128069 non-null  float64
#  11  SHOT_DIST                   128069 non-null  float64
#  12  PTS_TYPE                    128069 non-null  int64
#  13  SHOT_RESULT                 128069 non-null  object
#  14  CLOSEST_DEFENDER            128069 non-null  object
#  15  CLOSEST_DEFENDER_PLAYER_ID  128069 non-null  int64
#  16  CLOSE_DEF_DIST              128069 non-null  float64
#  17  FGM                         128069 non-null  int64
#  18  PTS                         128069 non-null  int64
#  19  player_name                 128069 non-null  object
#  20  player_id                   128069 non-null  int64
# dtypes: float64(4), int64(10), object(7)
# memory usage: 20.5+ MB

# %% [markdown]
# # Monotoni atributi
# Prvo cemo provjeriti postoje li monotoni atributi u našem skupu podataka

# %%
# provjera monotonih atributa
x.nunique()
# Out:
# GAME_ID                        904
# MATCHUP                       1808
# LOCATION                         2
# W                                2
# FINAL_MARGIN                    88
# SHOT_NUMBER                     38
# PERIOD                           7
# GAME_CLOCK                     719
# SHOT_CLOCK                     241
# DRIBBLES                        33
# TOUCH_TIME                     313
# SHOT_DIST                      448
# PTS_TYPE                         2
# SHOT_RESULT                      2
# CLOSEST_DEFENDER               473
# CLOSEST_DEFENDER_PLAYER_ID     474
# CLOSE_DEF_DIST                 299
# FGM                              2
# PTS                              3
# player_name                    281
# player_id                      281
# dtype: int64

# %% [markdown]
# Vidimo da su Game_id, Matchup, Player_Id i PLayer_Name glavni kandidati za monotone atribute. Izbacujemo Player_Id, Matchup i Game_Id.

# %%
#izbacivanje znacajki
x.drop(('GAME_ID'), axis=1, inplace=True)
x.drop(('player_id'), axis=1, inplace=True)
x.drop(('MATCHUP'), axis=1, inplace=True)

# %%
# nedostajuci podaci
x.isna().sum()
# Out:
# LOCATION                         0
# W                                0
# FINAL_MARGIN                     0
# SHOT_NUMBER                      0
# PERIOD                           0
# GAME_CLOCK                       0
# SHOT_CLOCK                    5567
# DRIBBLES                         0
# TOUCH_TIME                       0
# SHOT_DIST                        0
# PTS_TYPE                         0
# SHOT_RESULT                      0
# CLOSEST_DEFENDER                 0
# CLOSEST_DEFENDER_PLAYER_ID       0
# CLOSE_DEF_DIST                   0
# FGM                              0
# PTS                              0
# player_name                      0
# dtype: int64

# %% [markdown]
# Vidimo da Shot_Clock ima null vrijednosti. Imamo 128 068 zapisa. Znaci ne gubimo mnogo ako izbacimo zapise koji sadrze null vrijednosti.

# %%
x_tmp = x.copy()

x_tmp = x_tmp.loc[x_tmp.SHOT_CLOCK.notnull(), :]
x = x_tmp

# %%
# nedostajuci podaci
x.isna().sum()
# Out:
# LOCATION                      0
# W                             0
# FINAL_MARGIN                  0
# SHOT_NUMBER                   0
# PERIOD                        0
# GAME_CLOCK                    0
# SHOT_CLOCK                    0
# DRIBBLES                      0
# TOUCH_TIME                    0
# SHOT_DIST                     0
# PTS_TYPE                      0
# SHOT_RESULT                   0
# CLOSEST_DEFENDER              0
# CLOSEST_DEFENDER_PLAYER_ID    0
# CLOSE_DEF_DIST                0
# FGM                           0
# PTS                           0
# player_name                   0
# dtype: int64

# %% [markdown]
# Vidimo da vise nema null vrijednosti u Shot_Clock.

# %% [markdown]
# # Detaljniji opis značajki
# Pomocu metode describe mozemo vidjeti nama korisne informacije o svakoj značajki.

# %%
#opis znacajki
x.describe()
# Out:
#         FINAL_MARGIN    SHOT_NUMBER         PERIOD     SHOT_CLOCK  \
# count  122502.000000  122502.000000  122502.000000  122502.000000
# mean        0.252396       6.476164       2.471454      12.453344
# std        13.311418       4.681245       1.137898       5.763265
# min       -53.000000       1.000000       1.000000       0.000000
# 25%        -8.000000       3.000000       1.000000       8.200000
# 50%         1.000000       5.000000       2.000000      12.300000
# 75%         9.000000       9.000000       3.000000      16.675000
# max        53.000000      37.000000       7.000000      24.000000
#
#             DRIBBLES     TOUCH_TIME      SHOT_DIST       PTS_TYPE  \
# count  122502.000000  122502.000000  122502.000000  122502.000000
# mean        1.989233       2.748202      13.443758       2.258363
# std         3.411188       2.957237       8.777113       0.437736
# min         0.000000    -100.500000       0.000000       2.000000
# 25%         0.000000       0.900000       4.700000       2.000000
# 50%         1.000000       1.600000      13.400000       2.000000
# 75%         2.000000       3.700000      22.400000       3.000000
# max        32.000000      24.900000      43.500000       3.000000
#
#        CLOSEST_DEFENDER_PLAYER_ID  CLOSE_DEF_DIST            FGM  \
# count               122502.000000   122502.000000  122502.000000
# mean                159120.427977        4.121706       0.456156
# std                  78689.677900        2.751587       0.498076
# min                    708.000000        0.000000       0.000000
# 25%                 200745.000000        2.300000       0.000000
# 50%                 201949.000000        3.700000       0.000000
# 75%                 203079.000000        5.300000       1.000000
# max                 530027.000000       53.200000       1.000000
#
#                  PTS
# count  122502.000000
# mean        1.005469
# std         1.131129
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         2.000000
# max         3.000000

# %% [markdown]
# Vidimo da značajka Touch_Time ima negativne vrijednosti, što ne bi trebalo biti moguce. Isto tako znacajka Periods ima vrijednosti iznad 4.

# %%
#izbacivanje negativnih vrijednosti
y = x[x.TOUCH_TIME < 0 ]
#z = x[x.PERIOD > 4 ]
x = x.drop(y.index)
#x = x.drop(z.index)

# %%
#opis znacajki
x.describe()
# Out:
#         FINAL_MARGIN    SHOT_NUMBER         PERIOD     SHOT_CLOCK  \
# count  122203.000000  122203.000000  122203.000000  122203.000000
# mean        0.253603       6.475717       2.471641      12.450301
# std        13.312980       4.681851       1.137948       5.756509
# min       -53.000000       1.000000       1.000000       0.000000
# 25%        -8.000000       3.000000       1.000000       8.200000
# 50%         1.000000       5.000000       2.000000      12.300000
# 75%         9.000000       9.000000       3.000000      16.600000
# max        53.000000      37.000000       7.000000      24.000000
#
#             DRIBBLES     TOUCH_TIME      SHOT_DIST       PTS_TYPE  \
# count  122203.000000  122203.000000  122203.000000  122203.000000
# mean        1.994084       2.759785      13.449139       2.258652
# std         3.413942       2.935379       8.776124       0.437896
# min         0.000000       0.000000       0.000000       2.000000
# 25%         0.000000       0.900000       4.700000       2.000000
# 50%         1.000000       1.600000      13.400000       2.000000
# 75%         2.000000       3.700000      22.400000       3.000000
# max        32.000000      24.900000      43.500000       3.000000
#
#        CLOSEST_DEFENDER_PLAYER_ID  CLOSE_DEF_DIST            FGM  \
# count               122203.000000   122203.000000  122203.000000
# mean                159126.039713        4.122839       0.456495
# std                  78685.768017        2.751535       0.498106
# min                    708.000000        0.000000       0.000000
# 25%                 200745.000000        2.300000       0.000000
# 50%                 201949.000000        3.700000       0.000000
# 75%                 203079.000000        5.300000       1.000000
# max                 530027.000000       53.200000       1.000000
#
#                  PTS
# count  122203.000000
# mean        1.006260
# std         1.131276
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         2.000000
# max         3.000000

# %% [markdown]
# Sada vidimo da nema vise negativne vrijednosti u Touch_Time značajki.

# %% [markdown]
# # Vizualizacija
# Prvo cemo vizualizirati ostvarene poene preko histograma.

# %%
# histogram 1
plt.figure(figsize=(8,6))
plt.subplot(2,2,1)
plt.hist(x.PTS)
plt.xlabel('Ostvareni bodovi')
plt.axvline(x.PTS.mean(), color = 'red', label = 'mean')

# histogram 2 
plt.subplot(2,2,2)
plt.hist(x.PERIOD)
plt.xlabel('Bacanja po cetvrti')

# histogram 3 
plt.subplot(2,2,3)
plt.hist(x.SHOT_RESULT)
plt.xlabel('Uspjesnost')
plt.show()

# %% [markdown]
# - Histogram 1 lijepo vizualizira distribuciju ostvarenih poena po broju bacanja. Crvena linija predstavlja mean koji je ispao 1.
# - Histogram 2 nam pokazuje kolko je bacanja po cetvrti.
# - Histogram 3 nam pokazuje broj promasenih i pogodenih bacanja

# %% [markdown]
# Histogram 2 i 3 su nam korisni, medutim, ima ih smisla i spojiti.

# %%
#mask and grouping
mask_result = x.SHOT_RESULT == "made"
count_per_period_missed = x.loc[~mask_result,:].groupby('PERIOD').count().loc[:,'player_name'].values
count_per_period_made = x.loc[mask_result,:].groupby('PERIOD').count().loc[:,'player_name'].values
title_name = x.groupby('PERIOD').count().index.values

#plot
plt.figure(figsize=(10,6))
plt.bar(title_name, count_per_period_missed, color='red', label='missed')
plt.bar(title_name, count_per_period_made, color='green', label='made', bottom=count_per_period_missed)
plt.legend(loc='best')
plt.grid()
plt.show()

# %% [markdown]
# Na ovom histogramu vidimo broj bacanja po periodu, a i broj ostvarenih pogodaka medu tim bacanjima

# %% [markdown]
# Sljedece cemo koristiti box plot za distancu bacanja, broj driblinga i preostalo vrijeme napada.

# %%
#boxplot za udaljenost
plt.figure(figsize=(20,6))
plt.subplot(1,3,1)
plt.boxplot(x.SHOT_DIST)
plt.title('Box plot for Shot Distance')
#plt.show()

#boxplot za udaljenost
plt.subplot(1,3,2)
plt.boxplot(x.DRIBBLES)
plt.title('Box plot for Dribbles')

#boxplot za shot_clock
plt.subplot(1,3,3)
plt.boxplot(x.SHOT_CLOCK)
plt.title('Box plot for Shot Clock')
plt.show()

# %% [markdown]
# Mozemo vidjeti max i min vrijednosti, kao i median i kvartale. Minimalna vrijednost je brk ispod, dok je maksimalna brk iznad. Median je crtica na sredini pravokutnika, dok su kvartali donja i gornja stranica pravkutnika. Krugovi predstavljaju outliere.

# %% [markdown]
# Sljedeci je scatter plot koji prikazuje da li je bacanje uspjesno u ovisnosti o udaljenosti od kosa i najblizem obrambenom igracu.

# %%
#mask
mask_result = x.SHOT_RESULT == "made"

#scatter plot
plt.figure(figsize=(20,6))
plt.scatter(x.loc[~mask_result,'SHOT_DIST'], x.loc[~mask_result,'CLOSE_DEF_DIST'], s=10, alpha=0.5, c='r', label='missed')
plt.scatter(x.loc[mask_result,'SHOT_DIST'], x.loc[mask_result,'CLOSE_DEF_DIST'], alpha=0.5, marker='x', s = 25, c='g', label='made')
plt.xlabel('Shot distance')
plt.ylabel('Closest DEfender Distance')
plt.title('Scatter plot')
plt.grid()
plt.show()

# %% [markdown]
# Ovakav graf nam daje dobar nacin da vidimo individualna bacanja. Vidimo da velika vecina uspjesnih bacanja se dogodila kad je igrac blizu kosa. Vecina neuspjesnih bacanja je na vecoj udaljenosti od kosa u kombinaciji s vrlo bliskim obrambenim igracem.

# %% [markdown]
# ## Seaborn
# Sljedeca je mreza koristenjem seaborna. Znacajka kojemo cemo koristiti u mrezi i usporedivati odnose su Final_margin, Shot_Clock, Dribbles. Touch_Time, Shot_Distance i Shot_Result.

# %%
sns.set(rc={'figure.figsize':(25,15)})
sns.pairplot(x.loc[:,['FINAL_MARGIN', 'SHOT_CLOCK', 'DRIBBLES', 'TOUCH_TIME', 'SHOT_DIST', 'SHOT_RESULT']], hue="SHOT_RESULT", corner=True)
plt.show()

# %% [markdown]
# Dodatno, iskoristit cemo seabornov violinski graf za prikaz koliko je bacanja pogodeno ili promaseno u ovisnosti o distanci.Graf je i podijeljen ovisno o tome da li je bacanje bilo na domacem terenu (H) ili gostujucem (A)

# %%
sns.violinplot(x="SHOT_RESULT", y="SHOT_DIST", hue="LOCATION", data = x,palette="muted", split=True, inner="quartile")
plt.show()

# %% [markdown]
# # Drugi dio: Repliciranje rezultata

# %%
x['GAME_CLOCK'] = x['GAME_CLOCK'].apply(
    lambda x: 60*int(x.split(':')[0]) + int(x.split(':')[1]))
x.drop(('LOCATION'), axis=1, inplace=True)
x.drop(('W'), axis=1, inplace=True)
x['SHOT_RESULT'] = x['SHOT_RESULT'].map({'missed':0,'made':1,'unknown':0})

# %% [markdown]
# # Random forests

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from scipy.stats import randint

# %%
target = x.SHOT_RESULT
target
# Out:
# 0         1
# 1         0
# 3         0
# 4         0
# 5         0
#          ..
# 128063    1
# 128064    0
# 128065    1
# 128066    1
# 128067    0
# Name: SHOT_RESULT, Length: 122203, dtype: int64

# %%
xRF = x.copy()
xRF.drop(('SHOT_RESULT'), axis=1, inplace=True)
xRF.drop(('player_name'), axis=1, inplace=True)
xRF.drop(('CLOSEST_DEFENDER_PLAYER_ID'), axis=1, inplace=True)
xRF.drop(('CLOSEST_DEFENDER'), axis=1, inplace=True)
xRF.drop(('FGM'), axis=1, inplace=True)
xRF.drop(('PTS'), axis=1, inplace=True)
xRF
# Out:
#         FINAL_MARGIN  SHOT_NUMBER  PERIOD  GAME_CLOCK  SHOT_CLOCK  DRIBBLES  \
# 0                 24            1       1          69        10.8         2
# 1                 24            2       1          14         3.4         0
# 3                 24            4       2         707        10.3         2
# 4                 24            5       2         634        10.9         2
# 5                 24            6       2         495         9.1         2
# ...              ...          ...     ...         ...         ...       ...
# 128063           -16            4       2         305        15.3         2
# 128064           -16            5       3         112        18.3         5
# 128065           -16            6       4         688        19.8         4
# 128066           -16            7       4         670        23.0         2
# 128067           -16            8       4         157         9.1         4
#
#         TOUCH_TIME  SHOT_DIST  PTS_TYPE  CLOSE_DEF_DIST
# 0              1.9        7.7         2             1.3
# 1              0.8       28.2         3             6.1
# 3              1.9       17.2         2             3.4
# 4              2.7        3.7         2             1.1
# 5              4.4       18.4         2             2.6
# ...            ...        ...       ...             ...
# 128063         1.6        8.9         2             5.7
# 128064         6.2        8.7         2             0.8
# 128065         5.2        0.6         2             0.6
# 128066         4.2       16.9         2             4.2
# 128067         4.5       18.3         2             3.0
#
# [122203 rows x 10 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(xRF, target, test_size=0.1)

# %%
rf = RandomForestClassifier()
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.6043695278618771

# %%
cm = confusion_matrix(y_test, y_pred)

ConfusionMatrixDisplay(confusion_matrix=cm).plot();

# %% [markdown]
# # SVM

# %%
xSVM = xRF.copy()
xSVM
# Out:
#         FINAL_MARGIN  SHOT_NUMBER  PERIOD  GAME_CLOCK  SHOT_CLOCK  DRIBBLES  \
# 0                 24            1       1          69        10.8         2
# 1                 24            2       1          14         3.4         0
# 3                 24            4       2         707        10.3         2
# 4                 24            5       2         634        10.9         2
# 5                 24            6       2         495         9.1         2
# ...              ...          ...     ...         ...         ...       ...
# 128063           -16            4       2         305        15.3         2
# 128064           -16            5       3         112        18.3         5
# 128065           -16            6       4         688        19.8         4
# 128066           -16            7       4         670        23.0         2
# 128067           -16            8       4         157         9.1         4
#
#         TOUCH_TIME  SHOT_DIST  PTS_TYPE  CLOSE_DEF_DIST
# 0              1.9        7.7         2             1.3
# 1              0.8       28.2         3             6.1
# 3              1.9       17.2         2             3.4
# 4              2.7        3.7         2             1.1
# 5              4.4       18.4         2             2.6
# ...            ...        ...       ...             ...
# 128063         1.6        8.9         2             5.7
# 128064         6.2        8.7         2             0.8
# 128065         5.2        0.6         2             0.6
# 128066         4.2       16.9         2             4.2
# 128067         4.5       18.3         2             3.0
#
# [122203 rows x 10 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(xSVM, target, test_size=0.1,random_state=109)

# %%
#Import svm model
from sklearn import svm
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import SGDClassifier
from sklearn.svm import LinearSVC
#Create a svm Classifier
clf = make_pipeline(StandardScaler(),LinearSVC(dual=False, random_state=0, tol=1e-5))
clf.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
# Model Accuracy: how often is the classifier correct?
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.6073971033466983

# %%
cm = confusion_matrix(y_test, y_pred)

ConfusionMatrixDisplay(confusion_matrix=cm).plot();

# %% [markdown]
# # Neural Networks

# %%
xNeural = xRF.copy()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier

# %%
relu_scores = np.array([])
sigmoid_scores = np.array([])

X_train, X_test, y_train, y_test = train_test_split(xNeural, target) # test_size = .25 po defaultu

# default alpha je 0.0001 koji je i koristen u radu!
clf_relu = MLPClassifier(random_state=1, max_iter=300, hidden_layer_sizes=[50], alpha=0.001).fit(X_train, y_train) # RELU aktivacijska funkcija!
clf_sigmoid = MLPClassifier(random_state=1, max_iter=300, hidden_layer_sizes=[50], activation="logistic", alpha=0.001).fit(X_train, y_train) # RELU aktivacijska funkcija!

relu_scores = np.append(relu_scores, clf_relu.score(X_test, y_test))
sigmoid_scores = np.append(sigmoid_scores, clf_sigmoid.score(X_test, y_test))

# %%
print(f"relu_scores average: {np.average(relu_scores)}")
print(f"sigmoid_scores average: {np.average(sigmoid_scores)}")
# Out:
# relu_scores average: 0.5322902687309744
# sigmoid_scores average: 0.6164446335635495

# %%
X_train, X_test, y_train, y_test = train_test_split(xNeural, target, stratify=target, test_size=0.1) # test_size = .25 po defaultu
clf = MLPClassifier(random_state=1, max_iter=300, hidden_layer_sizes=[50], activation="logistic").fit(X_train, y_train) # RELU aktivacijska funkcija!
y_pred = clf.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

cm = confusion_matrix(y_test, y_pred)

ConfusionMatrixDisplay(confusion_matrix=cm).plot();
# Out:
# Accuracy: 0.6132067752229768

# %% [markdown]
# # Boosting

# %%
xBST = xRF.copy()
xBST
# Out:
#         FINAL_MARGIN  SHOT_NUMBER  PERIOD  GAME_CLOCK  SHOT_CLOCK  DRIBBLES  \
# 0                 24            1       1          69        10.8         2
# 1                 24            2       1          14         3.4         0
# 3                 24            4       2         707        10.3         2
# 4                 24            5       2         634        10.9         2
# 5                 24            6       2         495         9.1         2
# ...              ...          ...     ...         ...         ...       ...
# 128063           -16            4       2         305        15.3         2
# 128064           -16            5       3         112        18.3         5
# 128065           -16            6       4         688        19.8         4
# 128066           -16            7       4         670        23.0         2
# 128067           -16            8       4         157         9.1         4
#
#         TOUCH_TIME  SHOT_DIST  PTS_TYPE  CLOSE_DEF_DIST
# 0              1.9        7.7         2             1.3
# 1              0.8       28.2         3             6.1
# 3              1.9       17.2         2             3.4
# 4              2.7        3.7         2             1.1
# 5              4.4       18.4         2             2.6
# ...            ...        ...       ...             ...
# 128063         1.6        8.9         2             5.7
# 128064         6.2        8.7         2             0.8
# 128065         5.2        0.6         2             0.6
# 128066         4.2       16.9         2             4.2
# 128067         4.5       18.3         2             3.0
#
# [122203 rows x 10 columns]

# %%
from xgboost import XGBClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(xBST, target, stratify=target, test_size=0.1)

xgb_model = XGBClassifier(objective="binary:logistic").fit(X_train, y_train)

y_pred = xgb_model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

cm = confusion_matrix(y_test, y_pred)

ConfusionMatrixDisplay(confusion_matrix=cm).plot();
# Out:
# Accuracy: 0.6117339006627935

# %% [markdown]
# # Logisticka regresija

# %%
from sklearn.linear_model import LogisticRegression

xLin = xRF.copy()
xLin
# Out:
#         FINAL_MARGIN  SHOT_NUMBER  PERIOD  GAME_CLOCK  SHOT_CLOCK  DRIBBLES  \
# 0                 24            1       1          69        10.8         2
# 1                 24            2       1          14         3.4         0
# 3                 24            4       2         707        10.3         2
# 4                 24            5       2         634        10.9         2
# 5                 24            6       2         495         9.1         2
# ...              ...          ...     ...         ...         ...       ...
# 128063           -16            4       2         305        15.3         2
# 128064           -16            5       3         112        18.3         5
# 128065           -16            6       4         688        19.8         4
# 128066           -16            7       4         670        23.0         2
# 128067           -16            8       4         157         9.1         4
#
#         TOUCH_TIME  SHOT_DIST  PTS_TYPE  CLOSE_DEF_DIST
# 0              1.9        7.7         2             1.3
# 1              0.8       28.2         3             6.1
# 3              1.9       17.2         2             3.4
# 4              2.7        3.7         2             1.1
# 5              4.4       18.4         2             2.6
# ...            ...        ...       ...             ...
# 128063         1.6        8.9         2             5.7
# 128064         6.2        8.7         2             0.8
# 128065         5.2        0.6         2             0.6
# 128066         4.2       16.9         2             4.2
# 128067         4.5       18.3         2             3.0
#
# [122203 rows x 10 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(xLin, target, test_size=0.1)

# %%
clf = LogisticRegression(max_iter = 100000, random_state=16)
clf.fit(X_train, y_train)

# Predviđanje na testnom skupu
y_pred = clf.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

cm = confusion_matrix(y_test, y_pred)

ConfusionMatrixDisplay(confusion_matrix=cm).plot();
# Out:
# Accuracy: 0.6054332705997872

# %% [markdown]
# # Naivni Bayesov Klasifikator

# %%
from sklearn.model_selection import cross_val_score
from sklearn.naive_bayes import MultinomialNB

# %%
xBayes = xRF.copy()
xBayes['FINAL_MARGIN'] = xBayes['FINAL_MARGIN'].abs()
X_train, X_test, y_train, y_test = train_test_split(xBayes, target, test_size=0.1)
xBayes.describe()
# Out:
#         FINAL_MARGIN    SHOT_NUMBER         PERIOD     GAME_CLOCK  \
# count  122203.000000  122203.000000  122203.000000  122203.000000
# mean       10.783851       6.475717       2.471641     361.094269
# std         7.810720       4.681851       1.137948     202.030587
# min         1.000000       1.000000       1.000000       1.000000
# 25%         5.000000       3.000000       1.000000     187.000000
# 50%         9.000000       5.000000       2.000000     362.000000
# 75%        15.000000       9.000000       3.000000     536.000000
# max        53.000000      37.000000       7.000000     720.000000
#
#           SHOT_CLOCK       DRIBBLES     TOUCH_TIME      SHOT_DIST  \
# count  122203.000000  122203.000000  122203.000000  122203.000000
# mean       12.450301       1.994084       2.759785      13.449139
# std         5.756509       3.413942       2.935379       8.776124
# min         0.000000       0.000000       0.000000       0.000000
# 25%         8.200000       0.000000       0.900000       4.700000
# 50%        12.300000       1.000000       1.600000      13.400000
# 75%        16.600000       2.000000       3.700000      22.400000
# max        24.000000      32.000000      24.900000      43.500000
#
#             PTS_TYPE  CLOSE_DEF_DIST
# count  122203.000000   122203.000000
# mean        2.258652        4.122839
# std         0.437896        2.751535
# min         2.000000        0.000000
# 25%         2.000000        2.300000
# 50%         2.000000        3.700000
# 75%         3.000000        5.300000
# max         3.000000       53.200000

# %%
from sklearn.preprocessing import KBinsDiscretizer

est = KBinsDiscretizer(n_bins=5, encode='ordinal', strategy='uniform', subsample=None)
est.fit(xBayes.to_numpy())
xBayes = est.transform(xBayes.to_numpy())
xBayes
# Out:
# array([[2., 0., 0., ..., 0., 0., 0.],
#        [2., 0., 0., ..., 3., 4., 0.],
#        [2., 0., 0., ..., 1., 0., 0.],
#        ...,
#        [1., 0., 2., ..., 0., 0., 0.],
#        [1., 0., 2., ..., 1., 0., 0.],
#        [1., 0., 2., ..., 2., 0., 0.]])

# %%
clf = MultinomialNB(alpha=1.0)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

cm = confusion_matrix(y_test, y_pred)

ConfusionMatrixDisplay(confusion_matrix=cm).plot();
# Out:
# Accuracy: 0.5822764094591277
